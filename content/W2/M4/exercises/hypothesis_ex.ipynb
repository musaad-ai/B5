# %% [markdown]
# # Exercises: Hypothesis Testing

# %% [markdown]
# #### Hypothesis $H_a$: smoking (yes/no) is associated with time of visit (lunch/dinner)

# %% [markdown]
# Load the tips dataset from Seaborn

# %%
tips = sns.load_dataset("tips")
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Create a contingency table of the smoker and time variables

# %%
# YOUR CODE HERE

# %%
contingency_table
# Out:
# smoker  Yes   No
# time
# Lunch    23   45
# Dinner   70  106

# %% [markdown]
# Display the heatmap

# %%
# YOUR CODE HERE

# %% [markdown]
# Test the hypothesis using chi squared test:

# %%
# significance level
alpha = 0.05

# %%
# YOUR CODE HERE
# Out:
# p-value: 0.4771485672079724
# nope
