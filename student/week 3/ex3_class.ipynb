# %% [markdown]
# # M1.Ex3: Iris Classification

# %% [markdown]
# - Run: [**Open In Colab**](https://colab.research.google.com/github/HassanAlgoz/B5/blob/main/content/W3/M1/exercises/ex3_class.ipynb)
# - Dataset:`sklearn.datasets.load_iris()`

# %%
import pandas as pd
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# ![Iris Flowers](https://github.com/HassanAlgoz/B5/blob/main/content/W3/M1/assets/iris_flowers.png?raw=1)

# %% [markdown]
# ### Step 1.a Load the data

# %%
iris = sklearn.datasets.load_iris(as_frame=True)

# %% [markdown]
# ### Step 2.a Assign variables `X` to the features and `y` to the target

# %%
x = iris.data
y = iris.target
iris.frame["species"] = iris.target_names[iris.frame["target"]]

# %% [markdown]
# ### Step 2.b print the type of each

# %%
print(type(x))
print(type(y))
# Out:
# <class 'pandas.DataFrame'>
# <class 'pandas.Series'>

# %% [markdown]
# ### Step 2.c identify whether the target is categorical or numerical & whether the task is regression or classification

# %%
print(x.shape)
print(y.shape)
# the target is a categorical  and task is a classification
# Out:
# (150, 4)
# (150,)

# %% [markdown]
# ### Step 3. Identify the number of samples and columns of both the data matrix and the target

# %%
print(x.describe())
print(x.columns)
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'],
#       dtype='str')

# %%
y.describe()
# Out:
# count    150.000000
# mean       1.000000
# std        0.819232
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        2.000000
# max        2.000000
# Name: target, dtype: float64

# %% [markdown]
# ### Step 4. Summarize the distribution of the data (min, max, median, mean, and standard deviation)

# %%
x.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
# ### Step 5. Plot the features to identify separability. Can you see clearly distinguishable groups of points?

# %%
sns.scatterplot(data=iris.frame, x="sepal length (cm)", y="sepal width (cm)", hue="species")
# Out:
# <Axes: xlabel='sepal length (cm)', ylabel='sepal width (cm)'>

# %% [markdown]
# ### Step 6. Keep the following in "Steps 7" onwards
#
# 1. First model will trian on the features: `sepal length (cm)` & `sepal width (cm)`
# 2. Second model will train on the features: `petal length (cm)` & `petal width (cm)`
#
# Finally, evaluate and compare which of the two feature-sets scored better.
#
# Let's do both subsets now..

# %% [markdown]
# ### Step 6.a subset the features `sepal length (cm)` & `sepal width (cm)`

# %%
x_sepal = x[["sepal length (cm)", "sepal width (cm)"]]
x_sepal.head()
# Out:
#    sepal length (cm)  sepal width (cm)
# 0                5.1               3.5
# 1                4.9               3.0
# 2                4.7               3.2
# 3                4.6               3.1
# 4                5.0               3.6

# %% [markdown]
# ### Step 6.b subset the features `petal length (cm)` & `petal width (cm)`

# %%
x_petal = x[["petal length (cm)", "petal width (cm)"]]
x_petal.head()
# Out:
#    petal length (cm)  petal width (cm)
# 0                1.4               0.2
# 1                1.4               0.2
# 2                1.3               0.2
# 3                1.5               0.2
# 4                1.4               0.2

# %% [markdown]
# ### Step 7. Initialize 2 `LogisticRegression` models

# %%
model1 = LogisticRegression()
model2 = LogisticRegression()

# %% [markdown]
# ### Step 8. Split the dataset into train and test sets (remember to stratify by the target to account for class imbalance)

# %%
x_sep_tr, x_sep_te, x_pet_tr, x_pet_te, y_tr, y_te = train_test_split(
    x_sepal,
    x_petal,
    y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

# %% [markdown]
# ### Step 9.a Train both models

# %%
model1.fit(x_sep_tr, y_tr)
model2.fit(x_pet_tr, y_tr)
# Out:
# LogisticRegression()

# %% [markdown]
# ### Step 10. Evaluate and compare both models

# %%
from sklearn.metrics import accuracy_score

acc_sepal = accuracy_score(y_tr, model1.predict(x_sep_tr))
acc_petal = accuracy_score(y_tr, model2.predict(x_pet_tr))
print(f"Sepal model accuracy : {acc_sepal:.2%}")
print(f"Petal model accuracy : {acc_petal:.2%}")
# Out:
# Sepal model accuracy : 84.17%
# Petal model accuracy : 96.67%

# %% [markdown]
# ### Step 11. Which of the two subset of features better distinguishes iris flowers? Can you easily tell?

# %%
#by locking the accuracy scores we can  see the peetal is better 
if acc_petal > acc_sepal:
    print("Petal features better distinguish iris flowers.")
elif acc_sepal > acc_petal:
    print("Sepal features better distinguish iris flowers.")
else:
    print("Both subsets perform equally.")
# Out:
# Petal features better distinguish iris flowers.

# %% [markdown]
# ### Step 12. Use `DecisionBoundaryDisplay` to plot the learned decision boundary

# %%
from sklearn.inspection import DecisionBoundaryDisplay
DecisionBoundaryDisplay.from_estimator(
    model1,
    x_sep_tr,
    response_method="predict", 
    cmap="RdYlBu",
    alpha=0.5
    )
sns.scatterplot(
    data=iris.frame, x="sepal length (cm)", y="sepal width (cm)", hue="species")
# Out:
# <Axes: xlabel='sepal length (cm)', ylabel='sepal width (cm)'>

# %%
from sklearn.inspection import DecisionBoundaryDisplay

DecisionBoundaryDisplay.from_estimator(
    model2,
    x_pet_tr,
    response_method="predict", 
    cmap="RdYlBu",
    alpha=0.5
    )
sns.scatterplot(
    data=iris.frame, x="petal length (cm)", y="petal width (cm)", hue="species")
# Out:
# <Axes: xlabel='petal length (cm)', ylabel='petal width (cm)'>
