# %% [markdown]
# You can order print and ebook versions of *Think Python 3e* from
# [Bookshop.org](https://bookshop.org/a/98697/9781098155438) and
# [Amazon](https://www.amazon.com/_/dp/1098155432?smid=ATVPDKIKX0DER&_encoding=UTF8&tag=oreilly20-20&_encoding=UTF8&tag=greenteapre01-20&linkCode=ur2&linkId=e2a529f94920295d27ec8a06e757dc7c&camp=1789&creative=9325).

# %% [markdown]
# name : musaad alanazi

# %% [markdown]
# ## Glossary
#
# **function definition:**
# A statement that creates a function.
#
# **header:**
#  The first line of a function definition.
#
# **body:**
#  The sequence of statements inside a function definition.
#
# **function object:**
# A value created by a function definition.
# The name of the function is a variable that refers to a function object.
#
# **parameter:**
#  A name used inside a function to refer to the value passed as an argument.
#
# **loop:**
#  A statement that runs one or more statements, often repeatedly.
#
# **local variable:**
# A variable defined inside a function, and which can only be accessed inside the function.
#
# **stack diagram:**
# A graphical representation of a stack of functions, their variables, and the values they refer to.
#
# **frame:**
#  A box in a stack diagram that represents a function call.
#  It contains the local variables and parameters of the function.
#
# **traceback:**
#  A list of the functions that are executing, printed when an exception occurs.

# %% [markdown]
# ## Exercises

# %%
# This cell tells Jupyter to provide detailed debugging information
# when a runtime error occurs. Run it before working on the exercises.

# %xmode Verbose

# %% [markdown]
# ### Ask a virtual assistant
#
# The statements in a function or a `for` loop are indented by four spaces, by convention.
# But not everyone agrees with that convention.
# If you are curious about the history of this great debate, ask a virtual assistant to "tell me about spaces and tabs in Python".
#
# Virtual assistant are pretty good at writing small functions.
#
# 1. Ask your favorite VA to "Write a function called repeat that takes a string and an integer and prints the string the given number of times."
#
# 2. If the result uses a `for` loop, you could ask, "Can you do it without a for loop?"
#
# 3. Pick any other function in this chapter and ask a VA to write it. The challenge is to describe the function precisely enough to get what you want. Use the vocabulary you have learned so far in this book.
#
# Virtual assistants are also pretty good at debugging functions.
#
# 1. Ask a VA what's wrong with this version of `print_twice`.
#
#     ```
#     def print_twice(string):
#         print(cat)
#         print(cat)
#     ```
#
# And if you get stuck on any of the exercises below, consider asking a VA for help.

# %% [markdown]
# ### Exercise
#
# Write a function named `print_right` that takes a string named `text` as a parameter and prints the string with enough leading spaces that the last letter of the string is in the 40th column of the display.

# %%
# Solution goes here
def print_right(str):
    space=40-len(str)
    print(" "*space+str)

print_right("Monty")
print_right("Python's")
print_right("Flying Circus")
# Out:
#                                    Monty
#                                 Python's
#                            Flying Circus

# %% [markdown]
# Hint: Use the `len` function, the string concatenation operator (`+`) and the string repetition operator (`*`).
#
# Here's an example that shows how it should work.

# %%
print_right("Monty")
print_right("Python's")
print_right("Flying Circus")
# Out:
#                                    Monty
#                                 Python's
#                            Flying Circus

# %% [markdown]
# ### Exercise
#
# Write a function called `triangle` that takes a string and an integer and draws a pyramid with the given height, made up using copies of the string. Here's an example of a pyramid with `5` levels, using the string `'L'`.

# %%
# Solution goes here
def triangle(str, x):
        i=0
        while i <= x :
            print(str*i)
            i+=1
     

triangle('L',5)
# Out:
# L
# LL
# LLL
# LLLL
# LLLLL

# %%
triangle('L', 5)
# Out:
# L
# LL
# LLL
# LLLL
# LLLLL

# %% [markdown]
# ### Exercise
#
# Write a function called `rectangle` that takes a string and two integers and draws a rectangle with the given width and height, made up using copies of the string. Here's an example of a rectangle with width `5` and height `4`, made up of the string `'H'`.

# %%
# Solution goes here
def rec(str,w,h):
    i=0
    while i < h :
        print(str * w)
        i+=1


rec('H', 5, 4)
# Out:
# HHHHH
# HHHHH
# HHHHH
# HHHHH

# %%
rec('H', 5, 4)
# Out:
# HHHHH
# HHHHH
# HHHHH
# HHHHH

# %% [markdown]
# ### Exercise
#
# The song "99 Bottles of Beer" starts with this verse:
#
# > 99 bottles of beer on the wall
# > 99 bottles of beer
# > Take one down, pass it around
# > 98 bottles of beer on the wall
#
# Then the second verse is the same, except that it starts with 98 bottles and ends with 97. The song continues -- for a very long time -- until there are 0 bottles of beer.
#
# Write a function called `bottle_verse` that takes a number as a parameter and displays the verse that starts with the given number of bottles.
#
# Hint: Consider starting with a function that can print the first, second, or last line of the verse, and then use it to write `bottle_verse`.

# %%
# Solution goes here
def  bottle_verse(x):
    i=0
    while i < x :
     print( x,"bottles of beer on the wall  ")
     print( x,"bottles of beer  ")
     print( x,"Take one down, pass it around ")
     print( x-1,"bottles of beer on the wall  ")
     x-=1

bottle_verse(15)
# Out:
# 15 bottles of beer on the wall
# 15 bottles of beer
# 15 Take one down, pass it around
# 14 bottles of beer on the wall
# 14 bottles of beer on the wall
# 14 bottles of beer
# 14 Take one down, pass it around
# 13 bottles of beer on the wall
# 13 bottles of beer on the wall
# 13 bottles of beer
# 13 Take one down, pass it around
# 12 bottles of beer on the wall
# 12 bottles of beer on the wall
# 12 bottles of beer
# 12 Take one down, pass it around
# 11 bottles of beer on the wall
# 11 bottles of beer on the wall
# 11 bottles of beer
# 11 Take one down, pass it around
# 10 bottles of beer on the wall
# 10 bottles of beer on the wall
# 10 bottles of beer
# 10 Take one down, pass it around
# 9 bottles of beer on the wall
# 9 bottles of beer on the wall
# 9 bottles of beer
# 9 Take one down, pass it around
# 8 bottles of beer on the wall
# 8 bottles of beer on the wall
# 8 bottles of beer
# 8 Take one down, pass it around
# 7 bottles of beer on the wall
# 7 bottles of beer on the wall
# 7 bottles of beer
# 7 Take one down, pass it around
# 6 bottles of beer on the wall
# 6 bottles of beer on the wall
# 6 bottles of beer
# 6 Take one down, pass it around
# 5 bottles of beer on the wall
# 5 bottles of beer on the wall
# 5 bottles of beer
# 5 Take one down, pass it around
# 4 bottles of beer on the wall
# 4 bottles of beer on the wall
# 4 bottles of beer
# 4 Take one down, pass it around
# 3 bottles of beer on the wall
# 3 bottles of beer on the wall
# 3 bottles of beer
# 3 Take one down, pass it around
# 2 bottles of beer on the wall
# 2 bottles of beer on the wall
# 2 bottles of beer
# 2 Take one down, pass it around
# 1 bottles of beer on the wall
# 1 bottles of beer on the wall
# 1 bottles of beer
# 1 Take one down, pass it around
# 0 bottles of beer on the wall

# %%
# Solution goes here

# %% [markdown]
# Use this function call to display the first verse.

# %%
bottle_verse(99)
# Out:
# 99 bottles of beer on the wall
# 99 bottles of beer
# 99 Take one down, pass it around
# 98 bottles of beer on the wall
# 98 bottles of beer on the wall
# 98 bottles of beer
# 98 Take one down, pass it around
# 97 bottles of beer on the wall
# 97 bottles of beer on the wall
# 97 bottles of beer
# 97 Take one down, pass it around
# 96 bottles of beer on the wall
# 96 bottles of beer on the wall
# 96 bottles of beer
# 96 Take one down, pass it around
# 95 bottles of beer on the wall
# 95 bottles of beer on the wall
# 95 bottles of beer
# 95 Take one down, pass it around
# 94 bottles of beer on the wall
# 94 bottles of beer on the wall
# 94 bottles of beer
# 94 Take one down, pass it around
# 93 bottles of beer on the wall
# 93 bottles of beer on the wall
# 93 bottles of beer
# 93 Take one down, pass it around
# 92 bottles of beer on the wall
# 92 bottles of beer on the wall
# 92 bottles of beer
# 92 Take one down, pass it around
# 91 bottles of beer on the wall
# 91 bottles of beer on the wall
# 91 bottles of beer
# 91 Take one down, pass it around
# 90 bottles of beer on the wall
# 90 bottles of beer on the wall
# 90 bottles of beer
# 90 Take one down, pass it around
# 89 bottles of beer on the wall
# 89 bottles of beer on the wall
# 89 bottles of beer
# 89 Take one down, pass it around
# 88 bottles of beer on the wall
# 88 bottles of beer on the wall
# 88 bottles of beer
# 88 Take one down, pass it around
# 87 bottles of beer on the wall
# 87 bottles of beer on the wall
# 87 bottles of beer
# 87 Take one down, pass it around
# 86 bottles of beer on the wall
# 86 bottles of beer on the wall
# 86 bottles of beer
# 86 Take one down, pass it around
# 85 bottles of beer on the wall
# 85 bottles of beer on the wall
# 85 bottles of beer
# 85 Take one down, pass it around
# 84 bottles of beer on the wall
# 84 bottles of beer on the wall
# 84 bottles of beer
# 84 Take one down, pass it around
# 83 bottles of beer on the wall
# 83 bottles of beer on the wall
# 83 bottles of beer
# 83 Take one down, pass it around
# 82 bottles of beer on the wall
# 82 bottles of beer on the wall
# 82 bottles of beer
# 82 Take one down, pass it around
# 81 bottles of beer on the wall
# 81 bottles of beer on the wall
# 81 bottles of beer
# 81 Take one down, pass it around
# 80 bottles of beer on the wall
# 80 bottles of beer on the wall
# 80 bottles of beer
# 80 Take one down, pass it around
# 79 bottles of beer on the wall
# 79 bottles of beer on the wall
# 79 bottles of beer
# 79 Take one down, pass it around
# 78 bottles of beer on the wall
# 78 bottles of beer on the wall
# 78 bottles of beer
# 78 Take one down, pass it around
# 77 bottles of beer on the wall
# 77 bottles of beer on the wall
# 77 bottles of beer
# 77 Take one down, pass it around
# 76 bottles of beer on the wall
# 76 bottles of beer on the wall
# 76 bottles of beer
# 76 Take one down, pass it around
# 75 bottles of beer on the wall
# 75 bottles of beer on the wall
# 75 bottles of beer
# 75 Take one down, pass it around
# 74 bottles of beer on the wall
# 74 bottles of beer on the wall
# 74 bottles of beer
# 74 Take one down, pass it around
# 73 bottles of beer on the wall
# 73 bottles of beer on the wall
# 73 bottles of beer
# 73 Take one down, pass it around
# 72 bottles of beer on the wall
# 72 bottles of beer on the wall
# 72 bottles of beer
# 72 Take one down, pass it around
# 71 bottles of beer on the wall
# 71 bottles of beer on the wall
# 71 bottles of beer
# 71 Take one down, pass it around
# 70 bottles of beer on the wall
# 70 bottles of beer on the wall
# 70 bottles of beer
# 70 Take one down, pass it around
# 69 bottles of beer on the wall
# 69 bottles of beer on the wall
# 69 bottles of beer
# 69 Take one down, pass it around
# 68 bottles of beer on the wall
# 68 bottles of beer on the wall
# 68 bottles of beer
# 68 Take one down, pass it around
# 67 bottles of beer on the wall
# 67 bottles of beer on the wall
# 67 bottles of beer
# 67 Take one down, pass it around
# 66 bottles of beer on the wall
# 66 bottles of beer on the wall
# 66 bottles of beer
# 66 Take one down, pass it around
# 65 bottles of beer on the wall
# 65 bottles of beer on the wall
# 65 bottles of beer
# 65 Take one down, pass it around
# 64 bottles of beer on the wall
# 64 bottles of beer on the wall
# 64 bottles of beer
# 64 Take one down, pass it around
# 63 bottles of beer on the wall
# 63 bottles of beer on the wall
# 63 bottles of beer
# 63 Take one down, pass it around
# 62 bottles of beer on the wall
# 62 bottles of beer on the wall
# 62 bottles of beer
# 62 Take one down, pass it around
# 61 bottles of beer on the wall
# 61 bottles of beer on the wall
# 61 bottles of beer
# 61 Take one down, pass it around
# 60 bottles of beer on the wall
# 60 bottles of beer on the wall
# 60 bottles of beer
# 60 Take one down, pass it around
# 59 bottles of beer on the wall
# 59 bottles of beer on the wall
# 59 bottles of beer
# 59 Take one down, pass it around
# 58 bottles of beer on the wall
# 58 bottles of beer on the wall
# 58 bottles of beer
# 58 Take one down, pass it around
# 57 bottles of beer on the wall
# 57 bottles of beer on the wall
# 57 bottles of beer
# 57 Take one down, pass it around
# 56 bottles of beer on the wall
# 56 bottles of beer on the wall
# 56 bottles of beer
# 56 Take one down, pass it around
# 55 bottles of beer on the wall
# 55 bottles of beer on the wall
# 55 bottles of beer
# 55 Take one down, pass it around
# 54 bottles of beer on the wall
# 54 bottles of beer on the wall
# 54 bottles of beer
# 54 Take one down, pass it around
# 53 bottles of beer on the wall
# 53 bottles of beer on the wall
# 53 bottles of beer
# 53 Take one down, pass it around
# 52 bottles of beer on the wall
# 52 bottles of beer on the wall
# 52 bottles of beer
# 52 Take one down, pass it around
# 51 bottles of beer on the wall
# 51 bottles of beer on the wall
# 51 bottles of beer
# 51 Take one down, pass it around
# 50 bottles of beer on the wall
# 50 bottles of beer on the wall
# 50 bottles of beer
# 50 Take one down, pass it around
# 49 bottles of beer on the wall
# 49 bottles of beer on the wall
# 49 bottles of beer
# 49 Take one down, pass it around
# 48 bottles of beer on the wall
# 48 bottles of beer on the wall
# 48 bottles of beer
# 48 Take one down, pass it around
# 47 bottles of beer on the wall
# 47 bottles of beer on the wall
# 47 bottles of beer
# 47 Take one down, pass it around
# 46 bottles of beer on the wall
# 46 bottles of beer on the wall
# 46 bottles of beer
# 46 Take one down, pass it around
# 45 bottles of beer on the wall
# 45 bottles of beer on the wall
# 45 bottles of beer
# 45 Take one down, pass it around
# 44 bottles of beer on the wall
# 44 bottles of beer on the wall
# 44 bottles of beer
# 44 Take one down, pass it around
# 43 bottles of beer on the wall
# 43 bottles of beer on the wall
# 43 bottles of beer
# 43 Take one down, pass it around
# 42 bottles of beer on the wall
# 42 bottles of beer on the wall
# 42 bottles of beer
# 42 Take one down, pass it around
# 41 bottles of beer on the wall
# 41 bottles of beer on the wall
# 41 bottles of beer
# 41 Take one down, pass it around
# 40 bottles of beer on the wall
# 40 bottles of beer on the wall
# 40 bottles of beer
# 40 Take one down, pass it around
# 39 bottles of beer on the wall
# 39 bottles of beer on the wall
# 39 bottles of beer
# 39 Take one down, pass it around
# 38 bottles of beer on the wall
# 38 bottles of beer on the wall
# 38 bottles of beer
# 38 Take one down, pass it around
# 37 bottles of beer on the wall
# 37 bottles of beer on the wall
# 37 bottles of beer
# 37 Take one down, pass it around
# 36 bottles of beer on the wall
# 36 bottles of beer on the wall
# 36 bottles of beer
# 36 Take one down, pass it around
# 35 bottles of beer on the wall
# 35 bottles of beer on the wall
# 35 bottles of beer
# 35 Take one down, pass it around
# 34 bottles of beer on the wall
# 34 bottles of beer on the wall
# 34 bottles of beer
# 34 Take one down, pass it around
# 33 bottles of beer on the wall
# 33 bottles of beer on the wall
# 33 bottles of beer
# 33 Take one down, pass it around
# 32 bottles of beer on the wall
# 32 bottles of beer on the wall
# 32 bottles of beer
# 32 Take one down, pass it around
# 31 bottles of beer on the wall
# 31 bottles of beer on the wall
# 31 bottles of beer
# 31 Take one down, pass it around
# 30 bottles of beer on the wall
# 30 bottles of beer on the wall
# 30 bottles of beer
# 30 Take one down, pass it around
# 29 bottles of beer on the wall
# 29 bottles of beer on the wall
# 29 bottles of beer
# 29 Take one down, pass it around
# 28 bottles of beer on the wall
# 28 bottles of beer on the wall
# 28 bottles of beer
# 28 Take one down, pass it around
# 27 bottles of beer on the wall
# 27 bottles of beer on the wall
# 27 bottles of beer
# 27 Take one down, pass it around
# 26 bottles of beer on the wall
# 26 bottles of beer on the wall
# 26 bottles of beer
# 26 Take one down, pass it around
# 25 bottles of beer on the wall
# 25 bottles of beer on the wall
# 25 bottles of beer
# 25 Take one down, pass it around
# 24 bottles of beer on the wall
# 24 bottles of beer on the wall
# 24 bottles of beer
# 24 Take one down, pass it around
# 23 bottles of beer on the wall
# 23 bottles of beer on the wall
# 23 bottles of beer
# 23 Take one down, pass it around
# 22 bottles of beer on the wall
# 22 bottles of beer on the wall
# 22 bottles of beer
# 22 Take one down, pass it around
# 21 bottles of beer on the wall
# 21 bottles of beer on the wall
# 21 bottles of beer
# 21 Take one down, pass it around
# 20 bottles of beer on the wall
# 20 bottles of beer on the wall
# 20 bottles of beer
# 20 Take one down, pass it around
# 19 bottles of beer on the wall
# 19 bottles of beer on the wall
# 19 bottles of beer
# 19 Take one down, pass it around
# 18 bottles of beer on the wall
# 18 bottles of beer on the wall
# 18 bottles of beer
# 18 Take one down, pass it around
# 17 bottles of beer on the wall
# 17 bottles of beer on the wall
# 17 bottles of beer
# 17 Take one down, pass it around
# 16 bottles of beer on the wall
# 16 bottles of beer on the wall
# 16 bottles of beer
# 16 Take one down, pass it around
# 15 bottles of beer on the wall
# 15 bottles of beer on the wall
# 15 bottles of beer
# 15 Take one down, pass it around
# 14 bottles of beer on the wall
# 14 bottles of beer on the wall
# 14 bottles of beer
# 14 Take one down, pass it around
# 13 bottles of beer on the wall
# 13 bottles of beer on the wall
# 13 bottles of beer
# 13 Take one down, pass it around
# 12 bottles of beer on the wall
# 12 bottles of beer on the wall
# 12 bottles of beer
# 12 Take one down, pass it around
# 11 bottles of beer on the wall
# 11 bottles of beer on the wall
# 11 bottles of beer
# 11 Take one down, pass it around
# 10 bottles of beer on the wall
# 10 bottles of beer on the wall
# 10 bottles of beer
# 10 Take one down, pass it around
# 9 bottles of beer on the wall
# 9 bottles of beer on the wall
# 9 bottles of beer
# 9 Take one down, pass it around
# 8 bottles of beer on the wall
# 8 bottles of beer on the wall
# 8 bottles of beer
# 8 Take one down, pass it around
# 7 bottles of beer on the wall
# 7 bottles of beer on the wall
# 7 bottles of beer
# 7 Take one down, pass it around
# 6 bottles of beer on the wall
# 6 bottles of beer on the wall
# 6 bottles of beer
# 6 Take one down, pass it around
# 5 bottles of beer on the wall
# 5 bottles of beer on the wall
# 5 bottles of beer
# 5 Take one down, pass it around
# 4 bottles of beer on the wall
# 4 bottles of beer on the wall
# 4 bottles of beer
# 4 Take one down, pass it around
# 3 bottles of beer on the wall
# 3 bottles of beer on the wall
# 3 bottles of beer
# 3 Take one down, pass it around
# 2 bottles of beer on the wall
# 2 bottles of beer on the wall
# 2 bottles of beer
# 2 Take one down, pass it around
# 1 bottles of beer on the wall
# 1 bottles of beer on the wall
# 1 bottles of beer
# 1 Take one down, pass it around
# 0 bottles of beer on the wall

# %% [markdown]
# If you want to print the whole song, you can use this `for` loop, which counts down from `99` to `1`.
# You don't have to completely understand this example---we'll learn more about `for` loops and the `range` function later.

# %%
for n in range(99, 0, -1):
    bottle_verse(n)
    print()
# Out:
# 99 bottles of beer on the wall
# 99 bottles of beer
# 99 Take one down, pass it around
# 98 bottles of beer on the wall
# 98 bottles of beer on the wall
# 98 bottles of beer
# 98 Take one down, pass it around
# 97 bottles of beer on the wall
# 97 bottles of beer on the wall
# 97 bottles of beer
# 97 Take one down, pass it around
# 96 bottles of beer on the wall
# 96 bottles of beer on the wall
# 96 bottles of beer
# 96 Take one down, pass it around
# 95 bottles of beer on the wall
# 95 bottles of beer on the wall
# 95 bottles of beer
# 95 Take one down, pass it around
# 94 bottles of beer on the wall
# 94 bottles of beer on the wall
# 94 bottles of beer
# 94 Take one down, pass it around
# 93 bottles of beer on the wall
# 93 bottles of beer on the wall
# 93 bottles of beer
# 93 Take one down, pass it around
# 92 bottles of beer on the wall
# 92 bottles of beer on the wall
# 92 bottles of beer
# 92 Take one down, pass it around
# 91 bottles of beer on the wall
# 91 bottles of beer on the wall
# 91 bottles of beer
# 91 Take one down, pass it around
# 90 bottles of beer on the wall
# 90 bottles of beer on the wall
# 90 bottles of beer
# 90 Take one down, pass it around
# 89 bottles of beer on the wall
# 89 bottles of beer on the wall
# 89 bottles of beer
# 89 Take one down, pass it around
# 88 bottles of beer on the wall
# 88 bottles of beer on the wall
# 88 bottles of beer
# 88 Take one down, pass it around
# 87 bottles of beer on the wall
# 87 bottles of beer on the wall
# 87 bottles of beer
# 87 Take one down, pass it around
# 86 bottles of beer on the wall
# 86 bottles of beer on the wall
# 86 bottles of beer
# 86 Take one down, pass it around
# 85 bottles of beer on the wall
# 85 bottles of beer on the wall
# 85 bottles of beer
# 85 Take one down, pass it around
# 84 bottles of beer on the wall
# 84 bottles of beer on the wall
# 84 bottles of beer
# 84 Take one down, pass it around
# 83 bottles of beer on the wall
# 83 bottles of beer on the wall
# 83 bottles of beer
# 83 Take one down, pass it around
# 82 bottles of beer on the wall
# 82 bottles of beer on the wall
# 82 bottles of beer
# 82 Take one down, pass it around
# 81 bottles of beer on the wall
# 81 bottles of beer on the wall
# 81 bottles of beer
# 81 Take one down, pass it around
# 80 bottles of beer on the wall
# 80 bottles of beer on the wall
# 80 bottles of beer
# 80 Take one down, pass it around
# 79 bottles of beer on the wall
# 79 bottles of beer on the wall
# 79 bottles of beer
# 79 Take one down, pass it around
# 78 bottles of beer on the wall
# 78 bottles of beer on the wall
# 78 bottles of beer
# 78 Take one down, pass it around
# 77 bottles of beer on the wall
# 77 bottles of beer on the wall
# 77 bottles of beer
# 77 Take one down, pass it around
# 76 bottles of beer on the wall
# 76 bottles of beer on the wall
# 76 bottles of beer
# 76 Take one down, pass it around
# 75 bottles of beer on the wall
# 75 bottles of beer on the wall
# 75 bottles of beer
# 75 Take one down, pass it around
# 74 bottles of beer on the wall
# 74 bottles of beer on the wall
# 74 bottles of beer
# 74 Take one down, pass it around
# 73 bottles of beer on the wall
# 73 bottles of beer on the wall
# 73 bottles of beer
# 73 Take one down, pass it around
# 72 bottles of beer on the wall
# 72 bottles of beer on the wall
# 72 bottles of beer
# 72 Take one down, pass it around
# 71 bottles of beer on the wall
# 71 bottles of beer on the wall
# 71 bottles of beer
# 71 Take one down, pass it around
# 70 bottles of beer on the wall
# 70 bottles of beer on the wall
# 70 bottles of beer
# 70 Take one down, pass it around
# 69 bottles of beer on the wall
# 69 bottles of beer on the wall
# 69 bottles of beer
# 69 Take one down, pass it around
# 68 bottles of beer on the wall
# 68 bottles of beer on the wall
# 68 bottles of beer
# 68 Take one down, pass it around
# 67 bottles of beer on the wall
# 67 bottles of beer on the wall
# 67 bottles of beer
# 67 Take one down, pass it around
# 66 bottles of beer on the wall
# 66 bottles of beer on the wall
# 66 bottles of beer
# 66 Take one down, pass it around
# 65 bottles of beer on the wall
# 65 bottles of beer on the wall
# 65 bottles of beer
# 65 Take one down, pass it around
# 64 bottles of beer on the wall
# 64 bottles of beer on the wall
# 64 bottles of beer
# 64 Take one down, pass it around
# 63 bottles of beer on the wall
# 63 bottles of beer on the wall
# 63 bottles of beer
# 63 Take one down, pass it around
# 62 bottles of beer on the wall
# 62 bottles of beer on the wall
# 62 bottles of beer
# 62 Take one down, pass it around
# 61 bottles of beer on the wall
# 61 bottles of beer on the wall
# 61 bottles of beer
# 61 Take one down, pass it around
# 60 bottles of beer on the wall
# 60 bottles of beer on the wall
# 60 bottles of beer
# 60 Take one down, pass it around
# 59 bottles of beer on the wall
# 59 bottles of beer on the wall
# 59 bottles of beer
# 59 Take one down, pass it around
# 58 bottles of beer on the wall
# 58 bottles of beer on the wall
# 58 bottles of beer
# 58 Take one down, pass it around
# 57 bottles of beer on the wall
# 57 bottles of beer on the wall
# 57 bottles of beer
# 57 Take one down, pass it around
# 56 bottles of beer on the wall
# 56 bottles of beer on the wall
# 56 bottles of beer
# 56 Take one down, pass it around
# 55 bottles of beer on the wall
# 55 bottles of beer on the wall
# 55 bottles of beer
# 55 Take one down, pass it around
# 54 bottles of beer on the wall
# 54 bottles of beer on the wall
# 54 bottles of beer
# 54 Take one down, pass it around
# 53 bottles of beer on the wall
# 53 bottles of beer on the wall
# 53 bottles of beer
# 53 Take one down, pass it around
# 52 bottles of beer on the wall
# 52 bottles of beer on the wall
# 52 bottles of beer
# 52 Take one down, pass it around
# 51 bottles of beer on the wall
# 51 bottles of beer on the wall
# 51 bottles of beer
# 51 Take one down, pass it around
# 50 bottles of beer on the wall
# 50 bottles of beer on the wall
# 50 bottles of beer
# 50 Take one down, pass it around
# 49 bottles of beer on the wall
# 49 bottles of beer on the wall
# 49 bottles of beer
# 49 Take one down, pass it around
# 48 bottles of beer on the wall
# 48 bottles of beer on the wall
# 48 bottles of beer
# 48 Take one down, pass it around
# 47 bottles of beer on the wall
# 47 bottles of beer on the wall
# 47 bottles of beer
# 47 Take one down, pass it around
# 46 bottles of beer on the wall
# 46 bottles of beer on the wall
# 46 bottles of beer
# 46 Take one down, pass it around
# 45 bottles of beer on the wall
# 45 bottles of beer on the wall
# 45 bottles of beer
# 45 Take one down, pass it around
# 44 bottles of beer on the wall
# 44 bottles of beer on the wall
# 44 bottles of beer
# 44 Take one down, pass it around
# 43 bottles of beer on the wall
# 43 bottles of beer on the wall
# 43 bottles of beer
# 43 Take one down, pass it around
# 42 bottles of beer on the wall
# 42 bottles of beer on the wall
# 42 bottles of beer
# 42 Take one down, pass it around
# 41 bottles of beer on the wall
# 41 bottles of beer on the wall
# 41 bottles of beer
# 41 Take one down, pass it around
# 40 bottles of beer on the wall
# 40 bottles of beer on the wall
# 40 bottles of beer
# 40 Take one down, pass it around
# 39 bottles of beer on the wall
# 39 bottles of beer on the wall
# 39 bottles of beer
# 39 Take one down, pass it around
# 38 bottles of beer on the wall
# 38 bottles of beer on the wall
# 38 bottles of beer
# 38 Take one down, pass it around
# 37 bottles of beer on the wall
# 37 bottles of beer on the wall
# 37 bottles of beer
# 37 Take one down, pass it around
# 36 bottles of beer on the wall
# 36 bottles of beer on the wall
# 36 bottles of beer
# 36 Take one down, pass it around
# 35 bottles of beer on the wall
# 35 bottles of beer on the wall
# 35 bottles of beer
# 35 Take one down, pass it around
# 34 bottles of beer on the wall
# 34 bottles of beer on the wall
# 34 bottles of beer
# 34 Take one down, pass it around
# 33 bottles of beer on the wall
# 33 bottles of beer on the wall
# 33 bottles of beer
# 33 Take one down, pass it around
# 32 bottles of beer on the wall
# 32 bottles of beer on the wall
# 32 bottles of beer
# 32 Take one down, pass it around
# 31 bottles of beer on the wall
# 31 bottles of beer on the wall
# 31 bottles of beer
# 31 Take one down, pass it around
# 30 bottles of beer on the wall
# 30 bottles of beer on the wall
# 30 bottles of beer
# 30 Take one down, pass it around
# 29 bottles of beer on the wall
# 29 bottles of beer on the wall
# 29 bottles of beer
# 29 Take one down, pass it around
# 28 bottles of beer on the wall
# 28 bottles of beer on the wall
# 28 bottles of beer
# 28 Take one down, pass it around
# 27 bottles of beer on the wall
# 27 bottles of beer on the wall
# 27 bottles of beer
# 27 Take one down, pass it around
# 26 bottles of beer on the wall
# 26 bottles of beer on the wall
# 26 bottles of beer
# 26 Take one down, pass it around
# 25 bottles of beer on the wall
# 25 bottles of beer on the wall
# 25 bottles of beer
# 25 Take one down, pass it around
# 24 bottles of beer on the wall
# 24 bottles of beer on the wall
# 24 bottles of beer
# 24 Take one down, pass it around
# 23 bottles of beer on the wall
# 23 bottles of beer on the wall
# 23 bottles of beer
# 23 Take one down, pass it around
# 22 bottles of beer on the wall
# 22 bottles of beer on the wall
# 22 bottles of beer
# 22 Take one down, pass it around
# 21 bottles of beer on the wall
# 21 bottles of beer on the wall
# 21 bottles of beer
# 21 Take one down, pass it around
# 20 bottles of beer on the wall
# 20 bottles of beer on the wall
# 20 bottles of beer
# 20 Take one down, pass it around
# 19 bottles of beer on the wall
# 19 bottles of beer on the wall
# 19 bottles of beer
# 19 Take one down, pass it around
# 18 bottles of beer on the wall
# 18 bottles of beer on the wall
# 18 bottles of beer
# 18 Take one down, pass it around
# 17 bottles of beer on the wall
# 17 bottles of beer on the wall
# 17 bottles of beer
# 17 Take one down, pass it around
# 16 bottles of beer on the wall
# 16 bottles of beer on the wall
# 16 bottles of beer
# 16 Take one down, pass it around
# 15 bottles of beer on the wall
# 15 bottles of beer on the wall
# 15 bottles of beer
# 15 Take one down, pass it around
# 14 bottles of beer on the wall
# 14 bottles of beer on the wall
# 14 bottles of beer
# 14 Take one down, pass it around
# 13 bottles of beer on the wall
# 13 bottles of beer on the wall
# 13 bottles of beer
# 13 Take one down, pass it around
# 12 bottles of beer on the wall
# 12 bottles of beer on the wall
# 12 bottles of beer
# 12 Take one down, pass it around
# 11 bottles of beer on the wall
# 11 bottles of beer on the wall
# 11 bottles of beer
# 11 Take one down, pass it around
# 10 bottles of beer on the wall
# 10 bottles of beer on the wall
# 10 bottles of beer
# 10 Take one down, pass it around
# 9 bottles of beer on the wall
# 9 bottles of beer on the wall
# 9 bottles of beer
# 9 Take one down, pass it around
# 8 bottles of beer on the wall
# 8 bottles of beer on the wall
# 8 bottles of beer
# 8 Take one down, pass it around
# 7 bottles of beer on the wall
# 7 bottles of beer on the wall
# 7 bottles of beer
# 7 Take one down, pass it around
# 6 bottles of beer on the wall
# 6 bottles of beer on the wall
# 6 bottles of beer
# 6 Take one down, pass it around
# 5 bottles of beer on the wall
# 5 bottles of beer on the wall
# 5 bottles of beer
# 5 Take one down, pass it around
# 4 bottles of beer on the wall
# 4 bottles of beer on the wall
# 4 bottles of beer
# 4 Take one down, pass it around
# 3 bottles of beer on the wall
# 3 bottles of beer on the wall
# 3 bottles of beer
# 3 Take one down, pass it around
# 2 bottles of beer on the wall
# 2 bottles of beer on the wall
# 2 bottles of beer
# 2 Take one down, pass it around
# 1 bottles of beer on the wall
# 1 bottles of beer on the wall
# 1 bottles of beer
# 1 Take one down, pass it around
# 0 bottles of beer on the wall
#
# 98 bottles of beer on the wall
# 98 bottles of beer
# 98 Take one down, pass it around
# 97 bottles of beer on the wall
# 97 bottles of beer on the wall
# 97 bottles of beer
# 97 Take one down, pass it around
# 96 bottles of beer on the wall
# 96 bottles of beer on the wall
# 96 bottles of beer
# 96 Take one down, pass it around
# 95 bottles of beer on the wall
# 95 bottles of beer on the wall
# 95 bottles of beer
# 95 Take one down, pass it around
# 94 bottles of beer on the wall
# 94 bottles of beer on the wall
# 94 bottles of beer
# 94 Take one down, pass it around
# 93 bottles of beer on the wall
# 93 bottles of beer on the wall
# 93 bottles of beer
# 93 Take one down, pass it around
# 92 bottles of beer on the wall
# 92 bottles of beer on the wall
# 92 bottles of beer
# 92 Take one down, pass it around
# 91 bottles of beer on the wall
# 91 bottles of beer on the wall
# 91 bottles of beer
# 91 Take one down, pass it around
# 90 bottles of beer on the wall
# 90 bottles of beer on the wall
# 90 bottles of beer
# 90 Take one down, pass it around
# 89 bottles of beer on the wall
# 89 bottles of beer on the wall
# 89 bottles of beer
# 89 Take one down, pass it around
# 88 bottles of beer on the wall
# 88 bottles of beer on the wall
# 88 bottles of beer
# 88 Take one down, pass it around
# 87 bottles of beer on the wall
# 87 bottles of beer on the wall
# 87 bottles of beer
# 87 Take one down, pass it around
# 86 bottles of beer on the wall
# 86 bottles of beer on the wall
# 86 bottles of beer
# 86 Take one down, pass it around
# 85 bottles of beer on the wall
# 85 bottles of beer on the wall
# 85 bottles of beer
# 85 Take one down, pass it around
# 84 bottles of beer on the wall
# 84 bottles of beer on the wall
# 84 bottles of beer
# 84 Take one down, pass it around
# 83 bottles of beer on the wall
# 83 bottles of beer on the wall
# 83 bottles of beer
# 83 Take one down, pass it around
# 82 bottles of beer on the wall
# 82 bottles of beer on the wall
# 82 bottles of beer
# 82 Take one down, pass it around
# 81 bottles of beer on the wall
# 81 bottles of beer on the wall
# 81 bottles of beer
# 81 Take one down, pass it around
# 80 bottles of beer on the wall
# 80 bottles of beer on the wall
# 80 bottles of beer
# 80 Take one down, pass it around
# 79 bottles of beer on the wall
# 79 bottles of beer on the wall
# 79 bottles of beer
# 79 Take one down, pass it around
# 78 bottles of beer on the wall
# 78 bottles of beer on the wall
# 78 bottles of beer
# 78 Take one down, pass it around
# 77 bottles of beer on the wall
# 77 bottles of beer on the wall
# 77 bottles of beer
# 77 Take one down, pass it around
# 76 bottles of beer on the wall
# 76 bottles of beer on the wall
# 76 bottles of beer
# 76 Take one down, pass it around
# 75 bottles of beer on the wall
# 75 bottles of beer on the wall
# 75 bottles of beer
# 75 Take one down, pass it around
# 74 bottles of beer on the wall
# 74 bottles of beer on the wall
# 74 bottles of beer
# 74 Take one down, pass it around
# 73 bottles of beer on the wall
# 73 bottles of beer on the wall
# 73 bottles of beer
# 73 Take one down, pass it around
# 72 bottles of beer on the wall
# 72 bottles of beer on the wall
# 72 bottles of beer
# 72 Take one down, pass it around
# 71 bottles of beer on the wall
# 71 bottles of beer on the wall
# 71 bottles of beer
# 71 Take one down, pass it around
# 70 bottles of beer on the wall
# 70 bottles of beer on the wall
# 70 bottles of beer
# 70 Take one down, pass it around
# 69 bottles of beer on the wall
# 69 bottles of beer on the wall
# 69 bottles of beer
# 69 Take one down, pass it around
# 68 bottles of beer on the wall
# 68 bottles of beer on the wall
# 68 bottles of beer
# 68 Take one down, pass it around
# 67 bottles of beer on the wall
# 67 bottles of beer on the wall
# 67 bottles of beer
# 67 Take one down, pass it around
# 66 bottles of beer on the wall
# 66 bottles of beer on the wall
# 66 bottles of beer
# 66 Take one down, pass it around
# 65 bottles of beer on the wall
# 65 bottles of beer on the wall
# 65 bottles of beer
# 65 Take one down, pass it around
# 64 bottles of beer on the wall
# 64 bottles of beer on the wall
# 64 bottles of beer
# 64 Take one down, pass it around
# 63 bottles of beer on the wall
# 63 bottles of beer on the wall
# 63 bottles of beer
# 63 Take one down, pass it around
# 62 bottles of beer on the wall
# 62 bottles of beer on the wall
# 62 bottles of beer
# 62 Take one down, pass it around
# 61 bottles of beer on the wall
# 61 bottles of beer on the wall
# 61 bottles of beer
# 61 Take one down, pass it around
# 60 bottles of beer on the wall
# 60 bottles of beer on the wall
# 60 bottles of beer
# 60 Take one down, pass it around
# 59 bottles of beer on the wall
# 59 bottles of beer on the wall
# 59 bottles of beer
# 59 Take one down, pass it around
# 58 bottles of beer on the wall
# 58 bottles of beer on the wall
# 58 bottles of beer
# 58 Take one down, pass it around
# 57 bottles of beer on the wall
# 57 bottles of beer on the wall
# 57 bottles of beer
# 57 Take one down, pass it around
# 56 bottles of beer on the wall
# 56 bottles of beer on the wall
# 56 bottles of beer
# 56 Take one down, pass it around
# 55 bottles of beer on the wall
# 55 bottles of beer on the wall
# 55 bottles of beer
# 55 Take one down, pass it around
# 54 bottles of beer on the wall
# 54 bottles of beer on the wall
# 54 bottles of beer
# 54 Take one down, pass it around
# 53 bottles of beer on the wall
# 53 bottles of beer on the wall
# 53 bottles of beer
# 53 Take one down, pass it around
# 52 bottles of beer on the wall
# 52 bottles of beer on the wall
# 52 bottles of beer
# 52 Take one down, pass it around
# 51 bottles of beer on the wall
# 51 bottles of beer on the wall
# 51 bottles of beer
# 51 Take one down, pass it around
# 50 bottles of beer on the wall
# 50 bottles of beer on the wall
# 50 bottles of beer
# 50 Take one down, pass it around
# 49 bottles of beer on the wall
# 49 bottles of beer on the wall
# 49 bottles of beer
# 49 Take one down, pass it around
# 48 bottles of beer on the wall
# 48 bottles of beer on the wall
# 48 bottles of beer
# 48 Take one down, pass it around
# 47 bottles of beer on the wall
# 47 bottles of beer on the wall
# 47 bottles of beer
# 47 Take one down, pass it around
# 46 bottles of beer on the wall
# 46 bottles of beer on the wall
# 46 bottles of beer
# 46 Take one down, pass it around
# 45 bottles of beer on the wall
# 45 bottles of beer on the wall
# 45 bottles of beer
# 45 Take one down, pass it around
# 44 bottles of beer on the wall
# 44 bottles of beer on the wall
# 44 bottles of beer
# 44 Take one down, pass it around
# 43 bottles of beer on the wall
# 43 bottles of beer on the wall
# 43 bottles of beer
# 43 Take one down, pass it around
# 42 bottles of beer on the wall
# 42 bottles of beer on the wall
# 42 bottles of beer
# 42 Take one down, pass it around
# 41 bottles of beer on the wall
# 41 bottles of beer on the wall
# 41 bottles of beer
# 41 Take one down, pass it around
# 40 bottles of beer on the wall
# 40 bottles of beer on the wall
# 40 bottles of beer
# 40 Take one down, pass it around
# 39 bottles of beer on the wall
# 39 bottles of beer on the wall
# 39 bottles of beer
# 39 Take one down, pass it around
# 38 bottles of beer on the wall
# 38 bottles of beer on the wall
# 38 bottles of beer
# 38 Take one down, pass it around
# 37 bottles of beer on the wall
# 37 bottles of beer on the wall
# 37 bottles of beer
# 37 Take one down, pass it around
# 36 bottles of beer on the wall
# 36 bottles of beer on the wall
# 36 bottles of beer
# 36 Take one down, pass it around
# 35 bottles of beer on the wall
# 35 bottles of beer on the wall
# 35 bottles of beer
# 35 Take one down, pass it around
# 34 bottles of beer on the wall
# 34 bottles of beer on the wall
# 34 bottles of beer
# 34 Take one down, pass it around
# 33 bottles of beer on the wall
# 33 bottles of beer on the wall
# 33 bottles of beer
# 33 Take one down, pass it around
# 32 bottles of beer on the wall
# 32 bottles of beer on the wall
# 32 bottles of beer
# 32 Take one down, pass it around
# 31 bottles of beer on the wall
# 31 bottles of beer on the wall
# 31 bottles of beer
# 31 Take one down, pass it around
# 30 bottles of beer on the wall
# 30 bottles of beer on the wall
# 30 bottles of beer
# 30 Take one down, pass it around
# 29 bottles of beer on the wall
# 29 bottles of beer on the wall
# 29 bottles of beer
# 29 Take one down, pass it around
# 28 bottles of beer on the wall
# 28 bottles of beer on the wall
# 28 bottles of beer
# 28 Take one down, pass it around
# 27 bottles of beer on the wall
# 27 bottles of beer on the wall
# 27 bottles of beer
# 27 Take one down, pass it around
# 26 bottles of beer on the wall
# 26 bottles of beer on the wall
# 26 bottles of beer
# 26 Take one down, pass it around
# 25 bottles of beer on the wall
# 25 bottles of beer on the wall
# 25 bottles of beer
# 25 Take one down, pass it around
# 24 bottles of beer on the wall
# 24 bottles of beer on the wall
# 24 bottles of beer
# 24 Take one down, pass it around
# 23 bottles of beer on the wall
# 23 bottles of beer on the wall
# 23 bottles of beer
# 23 Take one down, pass it around
# 22 bottles of beer on the wall
# 22 bottles of beer on the wall
# 22 bottles of beer
# 22 Take one down, pass it around
# 21 bottles of beer on the wall
# 21 bottles of beer on the wall
# 21 bottles of beer
# 21 Take one down, pass it around
# 20 bottles of beer on the wall
# 20 bottles of beer on the wall
# 20 bottles of beer
# 20 Take one down, pass it around
# 19 bottles of beer on the wall
# 19 bottles of beer on the wall
# 19 bottles of beer
# 19 Take one down, pass it around
# 18 bottles of beer on the wall
# 18 bottles of beer on the wall
# 18 bottles of beer
# 18 Take one down, pass it around
# 17 bottles of beer on the wall
# 17 bottles of beer on the wall
# 17 bottles of beer
# 17 Take one down, pass it around
# 16 bottles of beer on the wall
# 16 bottles of beer on the wall
# 16 bottles of beer
# 16 Take one down, pass it around
# 15 bottles of beer on the wall
# 15 bottles of beer on the wall
# 15 bottles of beer
# 15 Take one down, pass it around
# 14 bottles of beer on the wall
# 14 bottles of beer on the wall
# 14 bottles of beer
# 14 Take one down, pass it around
# 13 bottles of beer on the wall
# 13 bottles of beer on the wall
# 13 bottles of beer
# 13 Take one down, pass it around
# 12 bottles of beer on the wall
# 12 bottles of beer on the wall
# 12 bottles of beer
# 12 Take one down, pass it around
# 11 bottles of beer on the wall
# 11 bottles of beer on the wall
# 11 bottles of beer
# 11 Take one down, pass it around
# 10 bottles of beer on the wall
# 10 bottles of beer on the wall
# 10 bottles of beer
# 10 Take one down, pass it around
# 9 bottles of beer on the wall
# 9 bottles of beer on the wall
# 9 bottles of beer
# 9 Take one down, pass it around
# 8 bottles of beer on the wall
# 8 bottles of beer on the wall
# 8 bottles of beer
# 8 Take one down, pass it around
# 7 bottles of beer on the wall
# 7 bottles of beer on the wall
# 7 bottles of beer
# 7 Take one down, pass it around
# 6 bottles of beer on the wall
# 6 bottles of beer on the wall
# 6 bottles of beer
# 6 Take one down, pass it around
# 5 bottles of beer on the wall
# 5 bottles of beer on the wall
# 5 bottles of beer
# 5 Take one down, pass it around
# 4 bottles of beer on the wall
# 4 bottles of beer on the wall
# 4 bottles of beer
# 4 Take one down, pass it around
# 3 bottles of beer on the wall
# 3 bottles of beer on the wall
# 3 bottles of beer
# 3 Take one down, pass it around
# 2 bottles of beer on the wall
# 2 bottles of beer on the wall
# 2 bottles of beer
# 2 Take one down, pass it around
# 1 bottles of beer on the wall
# 1 bottles of beer on the wall
# 1 bottles of beer
# 1 Take one down, pass it around
# 0 bottles of beer on the wall
#
# 97 bottles of beer on the wall
# 97 bottles of beer
# 97 Take one down, pass it around
# 96 bottles of beer on the wall
# 96 bottles of beer on the wall
# 96 bottles of beer
# 96 Take one down, pass it around
# 95 bottles of beer on the wall
# 95 bottles of beer on the wall
# 95 bottles of beer
# 95 Take one down, pass it around
# 94 bottles of beer on the wall
# 94 bottles of beer on the wall
# 94 bottles of beer
# 94 Take one down, pass it around
# 93 bottles of beer on the wall
# 93 bottles of beer on the wall
# 93 bottles of beer
# 93 Take one down, pass it around
# 92 bottles of beer on the wall
# 92 bottles of beer on the wall
# 92 bottles of beer
# 92 Take one down, pass it around
# 91 bottles of beer on the wall
# 91 bottles of beer on the wall
# 91 bottles of beer
# 91 Take one down, pass it around
# 90 bottles of beer on the wall
# 90 bottles of beer on the wall
# 90 bottles of beer
# 90 Take one down, pass it around
# 89 bottles of beer on the wall
# 89 bottles of beer on the wall
# 89 bottles of beer
# 89 Take one down, pass it around
# 88 bottles of beer on the wall
# 88 bottles of beer on the wall
# 88 bottles of beer
# 88 Take one down, pass it around
# 87 bottles of beer on the wall
# 87 bottles of beer on the wall
# 87 bottles of beer
# 87 Take one down, pass it around
# 86 bottles of beer on the wall
# 86 bottles of beer on the wall
# 86 bottles of beer
# 86 Take one down, pass it around
# 85 bottles of beer on the wall
# 85 bottles of beer on the wall
# 85 bottles of beer
# 85 Take one down, pass it around
# 84 bottles of beer on the wall
# 84 bottles of beer on the wall
# 84 bottles of beer
# 84 Take one down, pass it around
# 83 bottles of beer on the wall
# 83 bottles of beer on the wall
# 83 bottles of beer
# 83 Take one down, pass it around
# 82 bottles of beer on the wall
# 82 bottles of beer on the wall
# 82 bottles of beer
# 82 Take one down, pass it around
# 81 bottles of beer on the wall
# 81 bottles of beer on the wall
# 81 bottles of beer
# 81 Take one down, pass it around
# 80 bottles of beer on the wall
# 80 bottles of beer on the wall
# 80 bottles of beer
# 80 Take one down, pass it around
# 79 bottles of beer on the wall
# 79 bottles of beer on the wall
# 79 bottles of beer
# 79 Take one down, pass it around
# 78 bottles of beer on the wall
# 78 bottles of beer on the wall
# 78 bottles of beer
# 78 Take one down, pass it around
# 77 bottles of beer on the wall
# 77 bottles of beer on the wall
# 77 bottles of beer
# 77 Take one down, pass it around
# 76 bottles of beer on the wall
# 76 bottles of beer on the wall
# 76 bottles of beer
# 76 Take one down, pass it around
# 75 bottles of beer on the wall
# 75 bottles of beer on the wall
# 75 bottles of beer
# 75 Take one down, pass it around
# 74 bottles of beer on the wall
# 74 bottles of beer on the wall
# 74 bottles of beer
# 74 Take one down, pass it around
# 73 bottles of beer on the wall
# 73 bottles of beer on the wall
# 73 bottles of beer
# 73 Take one down, pass it around
# 72 bottles of beer on the wall
# 72 bottles of beer on the wall
# 72 bottles of beer
# 72 Take one down, pass it around
# 71 bottles of beer on the wall
# 71 bottles of beer on the wall
# 71 bottles of beer
# 71 Take one down, pass it around
# 70 bottles of beer on the wall
# 70 bottles of beer on the wall
# 70 bottles of beer
# 70 Take one down, pass it around
# 69 bottles of beer on the wall
# 69 bottles of beer on the wall
# 69 bottles of beer
# 69 Take one down, pass it around
# 68 bottles of beer on the wall
# 68 bottles of beer on the wall
# 68 bottles of beer
# 68 Take one down, pass it around
# 67 bottles of beer on the wall
# 67 bottles of beer on the wall
# 67 bottles of beer
# 67 Take one down, pass it around
# 66 bottles of beer on the wall
# 66 bottles of beer on the wall
# 66 bottles of beer
# 66 Take one down, pass it around
# 65 bottles of beer on the wall
# 65 bottles of beer on the wall
# 65 bottles of beer
# 65 Take one down, pass it around
# 64 bottles of beer on the wall
# 64 bottles of beer on the wall
# 64 bottles of beer
# 64 Take one down, pass it around
# 63 bottles of beer on the wall
# 63 bottles of beer on the wall
# 63 bottles of beer
# 63 Take one down, pass it around
# 62 bottles of beer on the wall
# 62 bottles of beer on the wall
# 62 bottles of beer
# 62 Take one down, pass it around
# 61 bottles of beer on the wall
# 61 bottles of beer on the wall
# 61 bottles of beer
# 61 Take one down, pass it around
# 60 bottles of beer on the wall
# 60 bottles of beer on the wall
# 60 bottles of beer
# 60 Take one down, pass it around
# 59 bottles of beer on the wall
# 59 bottles of beer on the wall
# 59 bottles of beer
# 59 Take one down, pass it around
# 58 bottles of beer on the wall
# 58 bottles of beer on the wall
# 58 bottles of beer
# 58 Take one down, pass it around
# 57 bottles of beer on the wall
# 57 bottles of beer on the wall
# 57 bottles of beer
# 57 Take one down, pass it around
# 56 bottles of beer on the wall
# 56 bottles of beer on the wall
# 56 bottles of beer
# 56 Take one down, pass it around
# 55 bottles of beer on the wall
# 55 bottles of beer on the wall
# 55 bottles of beer
# 55 Take one down, pass it around
# 54 bottles of beer on the wall
# 54 bottles of beer on the wall
# 54 bottles of beer
# 54 Take one down, pass it around
# 53 bottles of beer on the wall
# 53 bottles of beer on the wall
# 53 bottles of beer
# 53 Take one down, pass it around
# 52 bottles of beer on the wall
# 52 bottles of beer on the wall
# 52 bottles of beer
# 52 Take one down, pass it around
# 51 bottles of beer on the wall
# 51 bottles of beer on the wall
# 51 bottles of beer
# 51 Take one down, pass it around
# 50 bottles of beer on the wall
# 50 bottles of beer on the wall
# 50 bottles of beer
# 50 Take one down, pass it around
# 49 bottles of beer on the wall
# 49 bottles of beer on the wall
# 49 bottles of beer
# 49 Take one down, pass it around
# 48 bottles of beer on the wall
# 48 bottles of beer on the wall
# 48 bottles of beer
# 48 Take one down, pass it around
# 47 bottles of beer on the wall
# 47 bottles of beer on the wall
# 47 bottles of beer
# 47 Take one down, pass it around
# 46 bottles of beer on the wall
# 46 bottles of beer on the wall
# 46 bottles of beer
# 46 Take one down, pass it around
# 45 bottles of beer on the wall
# 45 bottles of beer on the wall
# 45 bottles of beer
# 45 Take one down, pass it around
# 44 bottles of beer on the wall
# 44 bottles of beer on the wall
# 44 bottles of beer
# 44 Take one down, pass it around
# 43 bottles of beer on the wall
# 43 bottles of beer on the wall
# 43 bottles of beer
# 43 Take one down, pass it around
# 42 bottles of beer on the wall
# 42 bottles of beer on the wall
# 42 bottles of beer
# 42 Take one down, pass it around
# 41 bottles of beer on the wall
# 41 bottles of beer on the wall
# 41 bottles of beer
# 41 Take one down, pass it around
# 40 bottles of beer on the wall
# 40 bottles of beer on the wall
# 40 bottles of beer
# 40 Take one down, pass it around
# 39 bottles of beer on the wall
# 39 bottles of beer on the wall
# 39 bottles of beer
# 39 Take one down, pass it around
# 38 bottles of beer on the wall
# 38 bottles of beer on the wall
# 38 bottles of beer
# 38 Take one down, pass it around
# 37 bottles of beer on the wall
# 37 bottles of beer on the wall
# 37 bottles of beer
# 37 Take one down, pass it around
# 36 bottles of beer on the wall
# 36 bottles of beer on the wall
# 36 bottles of beer
# 36 Take one down, pass it around
# 35 bottles of beer on the wall
# 35 bottles of beer on the wall
# 35 bottles of beer
# 35 Take one down, pass it around
# 34 bottles of beer on the wall
# 34 bottles of beer on the wall
# 34 bottles of beer
# 34 Take one down, pass it around
# 33 bottles of beer on the wall
# 33 bottles of beer on the wall
# 33 bottles of beer
# 33 Take one down, pass it around
# 32 bottles of beer on the wall
# 32 bottles of beer on the wall
# 32 bottles of beer
# 32 Take one down, pass it around
# 31 bottles of beer on the wall
# 31 bottles of beer on the wall
# 31 bottles of beer
# 31 Take one down, pass it around
# 30 bottles of beer on the wall
# 30 bottles of beer on the wall
# 30 bottles of beer
# 30 Take one down, pass it around
# 29 bottles of beer on the wall
# 29 bottles of beer on the wall
# 29 bottles of beer
# 29 Take one down, pass it around
# 28 bottles of beer on the wall
# 28 bottles of beer on the wall
# 28 bottles of beer
# 28 Take one down, pass it around
# 27 bottles of beer on the wall
# 27 bottles of beer on the wall
# 27 bottles of beer
# 27 Take one down, pass it around
# 26 bottles of beer on the wall
# 26 bottles of beer on the wall
# 26 bottles of beer
# 26 Take one down, pass it around
# 25 bottles of beer on the wall
# 25 bottles of beer on the wall
# 25 bottles of beer
# 25 Take one down, pass it around
# 24 bottles of beer on the wall
# 24 bottles of beer on the wall
# 24 bottles of beer
# 24 Take one down, pass it around
# 23 bottles of beer on the wall
# 23 bottles of beer on the wall
# 23 bottles of beer
# 23 Take one down, pass it around
# 22 bottles of beer on the wall
# 22 bottles of beer on the wall
# 22 bottles of beer
# 22 Take one down, pass it around
# 21 bottles of beer on the wall
# 21 bottles of beer on the wall
# 21 bottles of beer
# 21 Take one down, pass it around
# 20 bottles of beer on the wall
# 20 bottles of beer on the wall
# 20 bottles of beer
# 20 Take one down, pass it around
# 19 bottles of beer on the wall
# 19 bottles of beer on the wall
# 19 bottles of beer
# 19 Take one down, pass it around
# 18 bottles of beer on the wall
# 18 bottles of beer on the wall
# 18 bottles of beer
# 18 Take one down, pass it around
# 17 bottles of beer on the wall
# 17 bottles of beer on the wall
# 17 bottles of beer
# 17 Take one down, pass it around
# 16 bottles of beer on the wall
# 16 bottles of beer on the wall
# 16 bottles of beer
# 16 Take one down, pass it around
# 15 bottles of beer on the wall
# 15 bottles of beer on the wall
# 15 bottles of beer
# 15 Take one down, pass it around
# 14 bottles of beer on the wall
# 14 bottles of beer on the wall
# 14 bottles of beer
# 14 Take one down, pass it around
# 13 bottles of beer on the wall
# 13 bottles of beer on the wall
# 13 bottles of beer
# 13 Take one down, pass it around
# 12 bottles of beer on the wall
# 12 bottles of beer on the wall
# 12 bottles of beer
# 12 Take one down, pass it around
# 11 bottles of beer on the wall
# 11 bottles of beer on the wall
# 11 bottles of beer
# 11 Take one down, pass it around
# 10 bottles of beer on the wall
# 10 bottles of beer on the wall
# 10 bottles of beer
# 10 Take one down, pass it around
# 9 bottles of beer on the wall
# 9 bottles of beer on the wall
# 9 bottles of beer
# 9 Take one down, pass it around
# 8 bottles of beer on the wall
# 8 bottles of beer on the wall
# 8 bottles of beer
# 8 Take one down, pass it around
# 7 bottles of beer on the wall
# 7 bottles of beer on the wall
# 7 bottles of beer
# 7 Take one down, pass it around
# 6 bottles of beer on the wall
# 6 bottles of beer on the wall
# 6 bottles of beer
# 6 Take one down, pass it around
# 5 bottles of beer on the wall
# 5 bottles of beer on the wall
# 5 bottles of beer
# 5 Take one down, pass it around
# 4 bottles of beer on the wall
# 4 bottles of beer on the wall
# 4 bottles of beer
# 4 Take one down, pass it around
# 3 bottles of beer on the wall
# 3 bottles of beer on the wall
# 3 bottles of beer
# 3 Take one down, pass it around
# 2 bottles of beer on the wall
# 2 bottles of beer on the wall
# 2 bottles of beer
# 2 Take one down, pass it around
# 1 bottles of beer on the wall
# 1 bottles of beer on the wall
# 1 bottles of beer
# 1 Take one down, pass it around
# 0 bottles of beer on the wall
#
# 96 bottles of beer on the wall
# 96 bottles of beer
# 96 Take one down, pass it around
# 95 bottles of beer on the wall
# 95 bottles of beer on the wall
# 95 bottles of beer
# 95 Take one down, pass it around
# 94 bottles of beer on the wall
# 94 bottles of beer on the wall
# 94 bottles of beer
# 94 Take one down, pass it around
# 93 bottles of beer on the wall
# 93 bottles of beer on the wall
# 93 bottles of beer
# 93 Take one down, pass it around
# 92 bottles of beer on the wall
# 92 bottles of beer on the wall
# 92 bottles of beer
# 92 Take one down, pass it around
# 91 bottles of beer on the wall
# 91 bottles of beer on the wall
# 91 bottles of beer
# 91 Take one down, pass it around
# 90 bottles of beer on the wall
# 90 bottles of beer on the wall
# 90 bottles of beer
# 90 Take one down, pass it around
# 89 bottles of beer on the wall
# 89 bottles of beer on the wall
# 89 bottles of beer
# 89 Take one down, pass it around
# 88 bottles of beer on the wall
# 88 bottles of beer on the wall
# 88 bottles of beer
# 88 Take one down, pass it around
# 87 bottles of beer on the wall
# 87 bottles of beer on the wall
# 87 bottles of beer
# 87 Take one down, pass it around
# 86 bottles of beer on the wall
# 86 bottles of beer on the wall
# 86 bottles of beer
# 86 Take one down, pass it around
# 85 bottles of beer on the wall
# 85 bottles of beer on the wall
# 85 bottles of beer
# 85 Take one down, pass it around
# 84 bottles of beer on the wall
# 84 bottles of beer on the wall
# 84 bottles of beer
# 84 Take one down, pass it around
# 83 bottles of beer on the wall
# 83 bottles of beer on the wall
# 83 bottles of beer
# 83 Take one down, pass it around
# 82 bottles of beer on the wall
# 82 bottles of beer on the wall
# 82 bottles of beer
# 82 Take one down, pass it around
# 81 bottles of beer on the wall
# 81 bottles of beer on the wall
# 81 bottles of beer
# 81 Take one down, pass it around
# 80 bottles of beer on the wall
# 80 bottles of beer on the wall
# 80 bottles of beer
# 80 Take one down, pass it around
# 79 bottles of beer on the wall
# 79 bottles of beer on the wall
# 79 bottles of beer
# 79 Take one down, pass it around
# 78 bottles of beer on the wall
# 78 bottles of beer on the wall
# 78 bottles of beer
# 78 Take one down, pass it around
# 77 bottles of beer on the wall
# 77 bottles of beer on the wall
# 77 bottles of beer
# 77 Take one down, pass it around
# 76 bottles of beer on the wall
# 76 bottles of beer on the wall
# 76 bottles of beer
# 76 Take one down, pass it around
# 75 bottles of beer on the wall
# 75 bottles of beer on the wall
# 75 bottles of beer
# 75 Take one down, pass it around
# 74 bottles of beer on the wall
# 74 bottles of beer on the wall
# 74 bottles of beer
# 74 Take one down, pass it around
# 73 bottles of beer on the wall
# 73 bottles of beer on the wall
# 73 bottles of beer
# 73 Take one down, pass it around
# 72 bottles of beer on the wall
# 72 bottles of beer on the wall
# 72 bottles of beer
# 72 Take one down, pass it around
# 71 bottles of beer on the wall
# 71 bottles of beer on the wall
# 71 bottles of beer
# 71 Take one down, pass it around
# 70 bottles of beer on the wall
# 70 bottles of beer on the wall
# 70 bottles of beer
# 70 Take one down, pass it around
# 69 bottles of beer on the wall
# 69 bottles of beer on the wall
# 69 bottles of beer
# 69 Take one down, pass it around
# 68 bottles of beer on the wall
# 68 bottles of beer on the wall
# 68 bottles of beer
# 68 Take one down, pass it around
# 67 bottles of beer on the wall
# 67 bottles of beer on the wall
# 67 bottles of beer
# 67 Take one down, pass it around
# 66 bottles of beer on the wall
# 66 bottles of beer on the wall
# 66 bottles of beer
# 66 Take one down, pass it around
# 65 bottles of beer on the wall
# 65 bottles of beer on the wall
# 65 bottles of beer
# 65 Take one down, pass it around
# 64 bottles of beer on the wall
# 64 bottles of beer on the wall
# 64 bottles of beer
# 64 Take one down, pass it around
# 63 bottles of beer on the wall
# 63 bottles of beer on the wall
# 63 bottles of beer
# 63 Take one down, pass it around
# 62 bottles of beer on the wall
# 62 bottles of beer on the wall
# 62 bottles of beer
# 62 Take one down, pass it around
# 61 bottles of beer on the wall
# 61 bottles of beer on the wall
# 61 bottles of beer
# 61 Take one down, pass it around
# 60 bottles of beer on the wall
# 60 bottles of beer on the wall
# 60 bottles of beer
# 60 Take one down, pass it around
# 59 bottles of beer on the wall
# 59 bottles of beer on the wall
# 59 bottles of beer
# 59 Take one down, pass it around
# 58 bottles of beer on the wall
# 58 bottles of beer on the wall
# 58 bottles of beer
# 58 Take one down, pass it around
# 57 bottles of beer on the wall
# 57 bottles of beer on the wall
# 57 bottles of beer
# 57 Take one down, pass it around
# 56 bottles of beer on the wall
# 56 bottles of beer on the wall
# 56 bottles of beer
# 56 Take one down, pass it around
# 55 bottles of beer on the wall
# 55 bottles of beer on the wall
# 55 bottles of beer
# 55 Take one down, pass it around
# 54 bottles of beer on the wall
# 54 bottles of beer on the wall
# 54 bottles of beer
# 54 Take one down, pass it around
# 53 bottles of beer on the wall
# 53 bottles of beer on the wall
# 53 bottles of beer
# 53 Take one down, pass it around
# 52 bottles of beer on the wall
# 52 bottles of beer on the wall
# 52 bottles of beer
# 52 Take one down, pass it around
# 51 bottles of beer on the wall
# 51 bottles of beer on the wall
# 51 bottles of beer
# 51 Take one down, pass it around
# 50 bottles of beer on the wall
# 50 bottles of beer on the wall
# 50 bottles of beer
# 50 Take one down, pass it around
# 49 bottles of beer on the wall
# 49 bottles of beer on the wall
# 49 bottles of beer
# 49 Take one down, pass it around
# 48 bottles of beer on the wall
# 48 bottles of beer on the wall
# 48 bottles of beer
# 48 Take one down, pass it around
# 47 bottles of beer on the wall
# 47 bottles of beer on the wall
# 47 bottles of beer
# 47 Take one down, pass it around
# 46 bottles of beer on the wall
# 46 bottles of beer on the wall
# 46 bottles of beer
# 46 Take one down, pass it around
# 45 bottles of beer on the wall
# 45 bottles of beer on the wall
# 45 bottles of beer
# 45 Take one down, pass it around
# 44 bottles of beer on the wall
# 44 bottles of beer on the wall
# 44 bottles of beer
# 44 Take one down, pass it around
# 43 bottles of beer on the wall
# 43 bottles of beer on the wall
# 43 bottles of beer
# 43 Take one down, pass it around
# 42 bottles of beer on the wall
# 42 bottles of beer on the wall
# 42 bottles of beer
# 42 Take one down, pass it around
# 41 bottles of beer on the wall
# 41 bottles of beer on the wall
# 41 bottles of beer
# 41 Take one down, pass it around
# 40 bottles of beer on the wall
# 40 bottles of beer on the wall
# 40 bottles of beer
# 40 Take one down, pass it around
# 39 bottles of beer on the wall
# 39 bottles of beer on the wall
# 39 bottles of beer
# 39 Take one down, pass it around
# 38 bottles of beer on the wall
# 38 bottles of beer on the wall
# 38 bottles of beer
# 38 Take one down, pass it around
# 37 bottles of beer on the wall
# 37 bottles of beer on the wall
# 37 bottles of beer
# 37 Take one down, pass it around
# 36 bottles of beer on the wall
# 36 bottles of beer on the wall
# 36 bottles of beer
# 36 Take one down, pass it around
# 35 bottles of beer on the wall
# 35 bottles of beer on the wall
# 35 bottles of beer
# 35 Take one down, pass it around
# 34 bottles of beer on the wall
# 34 bottles of beer on the wall
# 34 bottles of beer
# 34 Take one down, pass it around
# 33 bottles of beer on the wall
# 33 bottles of beer on the wall
# 33 bottles of beer
# 33 Take one down, pass it around
# 32 bottles of beer on the wall
# 32 bottles of beer on the wall
# 32 bottles of beer
# 32 Take one down, pass it around
# 31 bottles of beer on the wall
# 31 bottles of beer on the wall
# 31 bottles of beer
# 31 Take one down, pass it around
# 30 bottles of beer on the wall
# 30 bottles of beer on the wall
# 30 bottles of beer
# 30 Take one down, pass it around
# 29 bottles of beer on the wall
# 29 bottles of beer on the wall
# 29 bottles of beer
# 29 Take one down, pass it around
# 28 bottles of beer on the wall
# 28 bottles of beer on the wall
# 28 bottles of beer
# 28 Take one down, pass it around
# 27 bottles of beer on the wall
# 27 bottles of beer on the wall
# 27 bottles of beer
# 27 Take one down, pass it around
# 26 bottles of beer on the wall
# 26 bottles of beer on the wall
# 26 bottles of beer
# 26 Take one down, pass it around
# 25 bottles of beer on the wall
# 25 bottles of beer on the wall
# 25 bottles of beer
# 25 Take one down, pass it around
# 24 bottles of beer on the wall
# 24 bottles of beer on the wall
# 24 bottles of beer
# 24 Take one down, pass it around
# 23 bottles of beer on the wall
# 23 bottles of beer on the wall
# 23 bottles of beer
# 23 Take one down, pass it around
# 22 bottles of beer on the wall
# 22 bottles of beer on the wall
# 22 bottles of beer
# 22 Take one down, pass it around
# 21 bottles of beer on the wall
# 21 bottles of beer on the wall
# 21 bottles of beer
# 21 Take one down, pass it around
# 20 bottles of beer on the wall
# 20 bottles of beer on the wall
# 20 bottles of beer
# 20 Take one down, pass it around
# 19 bottles of beer on the wall
# 19 bottles of beer on the wall
# 19 bottles of beer
# 19 Take one down, pass it around
# 18 bottles of beer on the wall
# 18 bottles of beer on the wall
# 18 bottles of beer
# 18 Take one down, pass it around
# 17 bottles of beer on the wall
# 17 bottles of beer on the wall
# 17 bottles of beer
# 17 Take one down, pass it around
# 16 bottles of beer on the wall
# 16 bottles of beer on the wall
# 16 bottles of beer
# 16 Take one down, pass it around
# 15 bottles of beer on the wall
# 15 bottles of beer on the wall
# 15 bottles of beer
# 15 Take one down, pass it around
# 14 bottles of beer on the wall
# 14 bottles of beer on the wall
# 14 bottles of beer
# 14 Take one down, pass it around
# 13 bottles of beer on the wall
# 13 bottles of beer on the wall
# 13 bottles of beer
# 13 Take one down, pass it around
# 12 bottles of beer on the wall
# 12 bottles of beer on the wall
# 12 bottles of beer
# 12 Take one down, pass it around
# 11 bottles of beer on the wall
# 11 bottles of beer on the wall
# 11 bottles of beer
# 11 Take one down, pass it around
# 10 bottles of beer on the wall
# 10 bottles of beer on the wall
# 10 bottles of beer
# 10 Take one down, pass it around
# 9 bottles of beer on the wall
# 9 bottles of beer on the wall
# 9 bottles of beer
# 9 Take one down, pass it around
# 8 bottles of beer on the wall
# 8 bottles of beer on the wall
# 8 bottles of beer
# 8 Take one down, pass it around
# 7 bottles of beer on the wall
# 7 bottles of beer on the wall
# 7 bottles of beer
# 7 Take one down, pass it around
# 6 bottles of beer on the wall
# 6 bottles of beer on the wall
# 6 bottles of beer
# 6 Take one down, pass it around
# 5 bottles of beer on the wall
# 5 bottles of beer on the wall
# 5 bottles of beer
# 5 Take one down, pass it around
# 4 bottles of beer on the wall
# 4 bottles of beer on the wall
# 4 bottles of beer
# 4 Take one down, pass it around
# 3 bottles of beer on the wall
# 3 bottles of beer on the wall
# 3 bottles of beer
# 3 Take one down, pass it around
# 2 bottles of beer on the wall
# 2 bottles of beer on the wall
# 2 bottles of beer
# 2 Take one down, pass it around
# 1 bottles of beer on the wall
# 1 bottles of beer on the wall
# 1 bottles of beer
# 1 Take one down, pass it around
# 0 bottles of beer on the wall
#
# 95 bottles of beer on the wall
# 95 bottles of beer
# 95 Take one down, pass it around
# 94 bottles of beer on the wall
# 94 bottles of beer on the wall
# 94 bottles of beer
# 94 Take one down, pass it around
# 93 bottles of beer on the wall
# 93 bottles of beer on the wall
# 93 bottles of beer
# 93 Take one down, pass it around
# 92 bottles of beer on the wall
# 92 bottles of beer on the wall
# 92 bottles of beer
# 92 Take one down, pass it around
# 91 bottles of beer on the wall
# 91 bottles of beer on the wall
# 91 bottles of beer
# 91 Take one down, pass it around
# 90 bottles of beer on the wall
# 90 bottles of beer on the wall
# 90 bottles of beer
# 90 Take one down, pass it around
# 89 bottles of beer on the wall
# 89 bottles of beer on the wall
# 89 bottles of beer
# 89 Take one down, pass it around
# 88 bottles of beer on the wall
# 88 bottles of beer on the wall
# 88 bottles of beer
# 88 Take one down, pass it around
# ...
# 16 bottles of beer
# 16 Take one down, pass it around
# 15 bottles of beer on the wall
# 15 bottles of beer on the wall
# 15 bottles of beer
# 15 Take one down, pass it around
# 14 bottles of beer on the wall
# 14 bottles of beer on the wall
# 14 bottles of beer
# 14 Take one down, pass it around
# 13 bottles of beer on the wall
# 13 bottles of beer on the wall
# 13 bottles of beer
# 13 Take one down, pass it around
# 12 bottles of beer on the wall
# 12 bottles of beer on the wall
# 12 bottles of beer
# 12 Take one down, pass it around
# 11 bottles of beer on the wall
# 11 bottles of beer on the wall
# 11 bottles of beer
# 11 Take one down, pass it around
# 10 bottles of beer on the wall
# 10 bottles of beer on the wall
# 10 bottles of beer
# 10 Take one down, pass it around
# 9 bottles of beer on the wall
# 9 bottles of beer on the wall
# 9 bottles of beer
# 9 Take one down, pass it around
# 8 bottles of beer on the wall
# 8 bottles of beer on the wall
# 8 bottles of beer
# 8 Take one down, pass it around
# 7 bottles of beer on the wall
# 7 bottles of beer on the wall
# 7 bottles of beer
# 7 Take one down, pass it around
# 6 bottles of beer on the wall
# 6 bottles of beer on the wall
# 6 bottles of beer
# 6 Take one down, pass it around
# 5 bottles of beer on the wall
# 5 bottles of beer on the wall
# 5 bottles of beer
# 5 Take one down, pass it around
# 4 bottles of beer on the wall
# 4 bottles of beer on the wall
# 4 bottles of beer
# 4 Take one down, pass it around
# 3 bottles of beer on the wall
# 3 bottles of beer on the wall
# 3 bottles of beer
# 3 Take one down, pass it around
# 2 bottles of beer on the wall
# 2 bottles of beer on the wall
# 2 bottles of beer
# 2 Take one down, pass it around
# 1 bottles of beer on the wall
# 1 bottles of beer on the wall
# 1 bottles of beer
# 1 Take one down, pass it around
# 0 bottles of beer on the wall
#
# 15 bottles of beer on the wall
# 15 bottles of beer
# 15 Take one down, pass it around
# 14 bottles of beer on the wall
# 14 bottles of beer on the wall
# 14 bottles of beer
# 14 Take one down, pass it around
# 13 bottles of beer on the wall
# 13 bottles of beer on the wall
# 13 bottles of beer
# 13 Take one down, pass it around
# 12 bottles of beer on the wall
# 12 bottles of beer on the wall
# 12 bottles of beer
# 12 Take one down, pass it around
# 11 bottles of beer on the wall
# 11 bottles of beer on the wall
# 11 bottles of beer
# 11 Take one down, pass it around
# 10 bottles of beer on the wall
# 10 bottles of beer on the wall
# 10 bottles of beer
# 10 Take one down, pass it around
# 9 bottles of beer on the wall
# 9 bottles of beer on the wall
# 9 bottles of beer
# 9 Take one down, pass it around
# 8 bottles of beer on the wall
# 8 bottles of beer on the wall
# 8 bottles of beer
# 8 Take one down, pass it around
# 7 bottles of beer on the wall
# 7 bottles of beer on the wall
# 7 bottles of beer
# 7 Take one down, pass it around
# 6 bottles of beer on the wall
# 6 bottles of beer on the wall
# 6 bottles of beer
# 6 Take one down, pass it around
# 5 bottles of beer on the wall
# 5 bottles of beer on the wall
# 5 bottles of beer
# 5 Take one down, pass it around
# 4 bottles of beer on the wall
# 4 bottles of beer on the wall
# 4 bottles of beer
# 4 Take one down, pass it around
# 3 bottles of beer on the wall
# 3 bottles of beer on the wall
# 3 bottles of beer
# 3 Take one down, pass it around
# 2 bottles of beer on the wall
# 2 bottles of beer on the wall
# 2 bottles of beer
# 2 Take one down, pass it around
# 1 bottles of beer on the wall
# 1 bottles of beer on the wall
# 1 bottles of beer
# 1 Take one down, pass it around
# 0 bottles of beer on the wall
#
# 14 bottles of beer on the wall
# 14 bottles of beer
# 14 Take one down, pass it around
# 13 bottles of beer on the wall
# 13 bottles of beer on the wall
# 13 bottles of beer
# 13 Take one down, pass it around
# 12 bottles of beer on the wall
# 12 bottles of beer on the wall
# 12 bottles of beer
# 12 Take one down, pass it around
# 11 bottles of beer on the wall
# 11 bottles of beer on the wall
# 11 bottles of beer
# 11 Take one down, pass it around
# 10 bottles of beer on the wall
# 10 bottles of beer on the wall
# 10 bottles of beer
# 10 Take one down, pass it around
# 9 bottles of beer on the wall
# 9 bottles of beer on the wall
# 9 bottles of beer
# 9 Take one down, pass it around
# 8 bottles of beer on the wall
# 8 bottles of beer on the wall
# 8 bottles of beer
# 8 Take one down, pass it around
# 7 bottles of beer on the wall
# 7 bottles of beer on the wall
# 7 bottles of beer
# 7 Take one down, pass it around
# 6 bottles of beer on the wall
# 6 bottles of beer on the wall
# 6 bottles of beer
# 6 Take one down, pass it around
# 5 bottles of beer on the wall
# 5 bottles of beer on the wall
# 5 bottles of beer
# 5 Take one down, pass it around
# 4 bottles of beer on the wall
# 4 bottles of beer on the wall
# 4 bottles of beer
# 4 Take one down, pass it around
# 3 bottles of beer on the wall
# 3 bottles of beer on the wall
# 3 bottles of beer
# 3 Take one down, pass it around
# 2 bottles of beer on the wall
# 2 bottles of beer on the wall
# 2 bottles of beer
# 2 Take one down, pass it around
# 1 bottles of beer on the wall
# 1 bottles of beer on the wall
# 1 bottles of beer
# 1 Take one down, pass it around
# 0 bottles of beer on the wall
#
# 13 bottles of beer on the wall
# 13 bottles of beer
# 13 Take one down, pass it around
# 12 bottles of beer on the wall
# 12 bottles of beer on the wall
# 12 bottles of beer
# 12 Take one down, pass it around
# 11 bottles of beer on the wall
# 11 bottles of beer on the wall
# 11 bottles of beer
# 11 Take one down, pass it around
# 10 bottles of beer on the wall
# 10 bottles of beer on the wall
# 10 bottles of beer
# 10 Take one down, pass it around
# 9 bottles of beer on the wall
# 9 bottles of beer on the wall
# 9 bottles of beer
# 9 Take one down, pass it around
# 8 bottles of beer on the wall
# 8 bottles of beer on the wall
# 8 bottles of beer
# 8 Take one down, pass it around
# 7 bottles of beer on the wall
# 7 bottles of beer on the wall
# 7 bottles of beer
# 7 Take one down, pass it around
# 6 bottles of beer on the wall
# 6 bottles of beer on the wall
# 6 bottles of beer
# 6 Take one down, pass it around
# 5 bottles of beer on the wall
# 5 bottles of beer on the wall
# 5 bottles of beer
# 5 Take one down, pass it around
# 4 bottles of beer on the wall
# 4 bottles of beer on the wall
# 4 bottles of beer
# 4 Take one down, pass it around
# 3 bottles of beer on the wall
# 3 bottles of beer on the wall
# 3 bottles of beer
# 3 Take one down, pass it around
# 2 bottles of beer on the wall
# 2 bottles of beer on the wall
# 2 bottles of beer
# 2 Take one down, pass it around
# 1 bottles of beer on the wall
# 1 bottles of beer on the wall
# 1 bottles of beer
# 1 Take one down, pass it around
# 0 bottles of beer on the wall
#
# 12 bottles of beer on the wall
# 12 bottles of beer
# 12 Take one down, pass it around
# 11 bottles of beer on the wall
# 11 bottles of beer on the wall
# 11 bottles of beer
# 11 Take one down, pass it around
# 10 bottles of beer on the wall
# 10 bottles of beer on the wall
# 10 bottles of beer
# 10 Take one down, pass it around
# 9 bottles of beer on the wall
# 9 bottles of beer on the wall
# 9 bottles of beer
# 9 Take one down, pass it around
# 8 bottles of beer on the wall
# 8 bottles of beer on the wall
# 8 bottles of beer
# 8 Take one down, pass it around
# 7 bottles of beer on the wall
# 7 bottles of beer on the wall
# 7 bottles of beer
# 7 Take one down, pass it around
# 6 bottles of beer on the wall
# 6 bottles of beer on the wall
# 6 bottles of beer
# 6 Take one down, pass it around
# 5 bottles of beer on the wall
# 5 bottles of beer on the wall
# 5 bottles of beer
# 5 Take one down, pass it around
# 4 bottles of beer on the wall
# 4 bottles of beer on the wall
# 4 bottles of beer
# 4 Take one down, pass it around
# 3 bottles of beer on the wall
# 3 bottles of beer on the wall
# 3 bottles of beer
# 3 Take one down, pass it around
# 2 bottles of beer on the wall
# 2 bottles of beer on the wall
# 2 bottles of beer
# 2 Take one down, pass it around
# 1 bottles of beer on the wall
# 1 bottles of beer on the wall
# 1 bottles of beer
# 1 Take one down, pass it around
# 0 bottles of beer on the wall
#
# 11 bottles of beer on the wall
# 11 bottles of beer
# 11 Take one down, pass it around
# 10 bottles of beer on the wall
# 10 bottles of beer on the wall
# 10 bottles of beer
# 10 Take one down, pass it around
# 9 bottles of beer on the wall
# 9 bottles of beer on the wall
# 9 bottles of beer
# 9 Take one down, pass it around
# 8 bottles of beer on the wall
# 8 bottles of beer on the wall
# 8 bottles of beer
# 8 Take one down, pass it around
# 7 bottles of beer on the wall
# 7 bottles of beer on the wall
# 7 bottles of beer
# 7 Take one down, pass it around
# 6 bottles of beer on the wall
# 6 bottles of beer on the wall
# 6 bottles of beer
# 6 Take one down, pass it around
# 5 bottles of beer on the wall
# 5 bottles of beer on the wall
# 5 bottles of beer
# 5 Take one down, pass it around
# 4 bottles of beer on the wall
# 4 bottles of beer on the wall
# 4 bottles of beer
# 4 Take one down, pass it around
# 3 bottles of beer on the wall
# 3 bottles of beer on the wall
# 3 bottles of beer
# 3 Take one down, pass it around
# 2 bottles of beer on the wall
# 2 bottles of beer on the wall
# 2 bottles of beer
# 2 Take one down, pass it around
# 1 bottles of beer on the wall
# 1 bottles of beer on the wall
# 1 bottles of beer
# 1 Take one down, pass it around
# 0 bottles of beer on the wall
#
# 10 bottles of beer on the wall
# 10 bottles of beer
# 10 Take one down, pass it around
# 9 bottles of beer on the wall
# 9 bottles of beer on the wall
# 9 bottles of beer
# 9 Take one down, pass it around
# 8 bottles of beer on the wall
# 8 bottles of beer on the wall
# 8 bottles of beer
# 8 Take one down, pass it around
# 7 bottles of beer on the wall
# 7 bottles of beer on the wall
# 7 bottles of beer
# 7 Take one down, pass it around
# 6 bottles of beer on the wall
# 6 bottles of beer on the wall
# 6 bottles of beer
# 6 Take one down, pass it around
# 5 bottles of beer on the wall
# 5 bottles of beer on the wall
# 5 bottles of beer
# 5 Take one down, pass it around
# 4 bottles of beer on the wall
# 4 bottles of beer on the wall
# 4 bottles of beer
# 4 Take one down, pass it around
# 3 bottles of beer on the wall
# 3 bottles of beer on the wall
# 3 bottles of beer
# 3 Take one down, pass it around
# 2 bottles of beer on the wall
# 2 bottles of beer on the wall
# 2 bottles of beer
# 2 Take one down, pass it around
# 1 bottles of beer on the wall
# 1 bottles of beer on the wall
# 1 bottles of beer
# 1 Take one down, pass it around
# 0 bottles of beer on the wall
#
# 9 bottles of beer on the wall
# 9 bottles of beer
# 9 Take one down, pass it around
# 8 bottles of beer on the wall
# 8 bottles of beer on the wall
# 8 bottles of beer
# 8 Take one down, pass it around
# 7 bottles of beer on the wall
# 7 bottles of beer on the wall
# 7 bottles of beer
# 7 Take one down, pass it around
# 6 bottles of beer on the wall
# 6 bottles of beer on the wall
# 6 bottles of beer
# 6 Take one down, pass it around
# 5 bottles of beer on the wall
# 5 bottles of beer on the wall
# 5 bottles of beer
# 5 Take one down, pass it around
# 4 bottles of beer on the wall
# 4 bottles of beer on the wall
# 4 bottles of beer
# 4 Take one down, pass it around
# 3 bottles of beer on the wall
# 3 bottles of beer on the wall
# 3 bottles of beer
# 3 Take one down, pass it around
# 2 bottles of beer on the wall
# 2 bottles of beer on the wall
# 2 bottles of beer
# 2 Take one down, pass it around
# 1 bottles of beer on the wall
# 1 bottles of beer on the wall
# 1 bottles of beer
# 1 Take one down, pass it around
# 0 bottles of beer on the wall
#
# 8 bottles of beer on the wall
# 8 bottles of beer
# 8 Take one down, pass it around
# 7 bottles of beer on the wall
# 7 bottles of beer on the wall
# 7 bottles of beer
# 7 Take one down, pass it around
# 6 bottles of beer on the wall
# 6 bottles of beer on the wall
# 6 bottles of beer
# 6 Take one down, pass it around
# 5 bottles of beer on the wall
# 5 bottles of beer on the wall
# 5 bottles of beer
# 5 Take one down, pass it around
# 4 bottles of beer on the wall
# 4 bottles of beer on the wall
# 4 bottles of beer
# 4 Take one down, pass it around
# 3 bottles of beer on the wall
# 3 bottles of beer on the wall
# 3 bottles of beer
# 3 Take one down, pass it around
# 2 bottles of beer on the wall
# 2 bottles of beer on the wall
# 2 bottles of beer
# 2 Take one down, pass it around
# 1 bottles of beer on the wall
# 1 bottles of beer on the wall
# 1 bottles of beer
# 1 Take one down, pass it around
# 0 bottles of beer on the wall
#
# 7 bottles of beer on the wall
# 7 bottles of beer
# 7 Take one down, pass it around
# 6 bottles of beer on the wall
# 6 bottles of beer on the wall
# 6 bottles of beer
# 6 Take one down, pass it around
# 5 bottles of beer on the wall
# 5 bottles of beer on the wall
# 5 bottles of beer
# 5 Take one down, pass it around
# 4 bottles of beer on the wall
# 4 bottles of beer on the wall
# 4 bottles of beer
# 4 Take one down, pass it around
# 3 bottles of beer on the wall
# 3 bottles of beer on the wall
# 3 bottles of beer
# 3 Take one down, pass it around
# 2 bottles of beer on the wall
# 2 bottles of beer on the wall
# 2 bottles of beer
# 2 Take one down, pass it around
# 1 bottles of beer on the wall
# 1 bottles of beer on the wall
# 1 bottles of beer
# 1 Take one down, pass it around
# 0 bottles of beer on the wall
#
# 6 bottles of beer on the wall
# 6 bottles of beer
# 6 Take one down, pass it around
# 5 bottles of beer on the wall
# 5 bottles of beer on the wall
# 5 bottles of beer
# 5 Take one down, pass it around
# 4 bottles of beer on the wall
# 4 bottles of beer on the wall
# 4 bottles of beer
# 4 Take one down, pass it around
# 3 bottles of beer on the wall
# 3 bottles of beer on the wall
# 3 bottles of beer
# 3 Take one down, pass it around
# 2 bottles of beer on the wall
# 2 bottles of beer on the wall
# 2 bottles of beer
# 2 Take one down, pass it around
# 1 bottles of beer on the wall
# 1 bottles of beer on the wall
# 1 bottles of beer
# 1 Take one down, pass it around
# 0 bottles of beer on the wall
#
# 5 bottles of beer on the wall
# 5 bottles of beer
# 5 Take one down, pass it around
# 4 bottles of beer on the wall
# 4 bottles of beer on the wall
# 4 bottles of beer
# 4 Take one down, pass it around
# 3 bottles of beer on the wall
# 3 bottles of beer on the wall
# 3 bottles of beer
# 3 Take one down, pass it around
# 2 bottles of beer on the wall
# 2 bottles of beer on the wall
# 2 bottles of beer
# 2 Take one down, pass it around
# 1 bottles of beer on the wall
# 1 bottles of beer on the wall
# 1 bottles of beer
# 1 Take one down, pass it around
# 0 bottles of beer on the wall
#
# 4 bottles of beer on the wall
# 4 bottles of beer
# 4 Take one down, pass it around
# 3 bottles of beer on the wall
# 3 bottles of beer on the wall
# 3 bottles of beer
# 3 Take one down, pass it around
# 2 bottles of beer on the wall
# 2 bottles of beer on the wall
# 2 bottles of beer
# 2 Take one down, pass it around
# 1 bottles of beer on the wall
# 1 bottles of beer on the wall
# 1 bottles of beer
# 1 Take one down, pass it around
# 0 bottles of beer on the wall
#
# 3 bottles of beer on the wall
# 3 bottles of beer
# 3 Take one down, pass it around
# 2 bottles of beer on the wall
# 2 bottles of beer on the wall
# 2 bottles of beer
# 2 Take one down, pass it around
# 1 bottles of beer on the wall
# 1 bottles of beer on the wall
# 1 bottles of beer
# 1 Take one down, pass it around
# 0 bottles of beer on the wall
#
# 2 bottles of beer on the wall
# 2 bottles of beer
# 2 Take one down, pass it around
# 1 bottles of beer on the wall
# 1 bottles of beer on the wall
# 1 bottles of beer
# 1 Take one down, pass it around
# 0 bottles of beer on the wall
#
# 1 bottles of beer on the wall
# 1 bottles of beer
# 1 Take one down, pass it around
# 0 bottles of beer on the wall

# %% [markdown]
# [Think Python: 3rd Edition](https://allendowney.github.io/ThinkPython/index.html)
#
# Copyright 2024 [Allen B. Downey](https://allendowney.com)
#
# Code license: [MIT License](https://mit-license.org/)
#
# Text license: [Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International](https://creativecommons.org/licenses/by-nc-sa/4.0/)
